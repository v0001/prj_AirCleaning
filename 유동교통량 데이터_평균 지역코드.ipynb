# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
np.__version__, pd.__version__
# Out:
# ('1.18.1', '1.0.1')

# %%
ORIGIN_PATH = 'C:/Users/guswj/Desktop/py_projects/Project_AirCleaning/data/'
# Origin Path = 권인의 local data path

# %%
# 2017~2020 1월 데이터를 추출하여 지점명이 어떻게 변화하고 추가/삭제 되었는지 확인 
path = ORIGIN_PATH + 'Seoul_Traffic/2020/01월 서울시 교통량 조사자료.xlsx' 
df_202001=pd.read_excel(path,encoding='utf-8', sheet_name = 1)

df_202001.head()
# Out:
#          일자 요일        지점명  지점번호  방향            구분     0시     1시     2시     3시  \
# 0  20200101  수  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  712.0  645.0  437.0  309.0
# 1  20200102  목  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  315.0  222.0  186.0  165.0
# 2  20200103  금  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  632.0  457.0  295.0  236.0
# 3  20200104  토  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  740.0  518.0  388.0  331.0
# 4  20200105  일  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  533.0  424.0  297.0  230.0
#
#    ...     14시     15시     16시     17시     18시     19시     20시     21시  \
# 0  ...  1472.0  1416.0  1483.0  1329.0  1157.0  1014.0   954.0   849.0
# 1  ...  1792.0  1897.0  1842.0  2061.0  1994.0  1443.0  1233.0  1165.0
# 2  ...  2004.0  1929.0  2049.0  2140.0  2178.0  1654.0  1356.0  1260.0
# 3  ...  1837.0  1788.0  1588.0  1669.0  1530.0  1222.0  1143.0  1089.0
# 4  ...  1634.0  1673.0  1494.0  1429.0  1288.0  1035.0   987.0   884.0
#
#       22시    23시
# 0   780.0  480.0
# 1  1094.0  852.0
# ...

# %% [markdown]
# for i in range(2017,2021,1):
#     target_period = f'{i}01'
#     targetname_file = 'df_' + target_period
#     targetname_col = 'unique_cols_' + target_period
#     targetname_point = 'unique_point_' + target_period
#     print(targetname_file, target_period, '지점명 : ' , targetname_col, '지점번호 : ', targetname_point)
#
#     targetname_file.head()
#
#     targetname_col = targetname_file['지점명'].unique()
#     targetname_point = targetname_file['지점번호'].unique()
#
#     print(target_period, '지점명 : ' , targetname_col, '지점번호 : ', targetname_point)

# %% [markdown]
# unique_cols_201701 = df_201701['지점명'].unique()
# unique_point_201701 = df_201701['지점번호'].unique()
# unique_cols_201701.shape, unique_point_201701.shape

# %% [markdown]
# unique_cols_201801 = df_201801['지점명'].unique()
# unique_point_201801 = df_201801['지점번호'].unique()
# unique_cols_201801.shape, unique_point_201801.shape

# %% [markdown]
# unique_cols_201901 = df_201901['지점명'].unique()
# unique_point_201901 = df_201901['지점번호'].unique()
# unique_cols_201901.shape, unique_point_201901.shape

# %% [markdown]
# unique_cols_202001 = df_202001['지점명'].unique()
# unique_point_202001 = df_202001['지점번호'].unique()
# unique_cols_202001.shape, unique_point_202001.shape

# %% [markdown]
# # 2017에는 있고 2018년에는 없는 도로명
#
# comparison_2017n2018 = set(unique_point_201701)&set(unique_point_201801)
# set(unique_point_201701)-comparison_2017n2018

# %% [markdown]
# # 2018에는 있고 2017년에는 없는 도로명
#
# set(unique_point_201801)-comparison_2017n2018

# %% [markdown]
# # 2018년도는 있고 2019년은 없는 도로명
#
# comparison_2018n2019 = set(unique_point_201801)&set(unique_point_201901)
# set(unique_point_201801)-comparison_2018n2019

# %% [markdown]
# # 2019년도는 있고 2018년은 없는 도로명
#
# set(unique_point_201901)-comparison_2018n2019

# %% [markdown]
# # 2019년도는 있고 2020년은 없는 도로명
#
# comparison_2019n2020 = set(unique_point_202001)&set(unique_point_201901)
# set(unique_point_201901)-comparison_2019n2020

# %% [markdown]
# set(unique_point_202001)-comparison_2019n2020

# %% [markdown]
# df_202001.dtypes

# %% [markdown]
# np.mean(df_202001[df_202001.isnull() == False][['0시', '1시', '2시', '3시', '4시', '5시',
#        '6시', '7시', '8시', '9시', '10시', '11시', '12시', '13시', '14시', '15시', '16시',
#        '17시', '18시', '19시', '20시', '21시', '22시', '23시']],axis=1)

# %% [markdown]
# cols = df_202001['지점번호'].unique()

# %% [markdown]
# df_202001['Avg'] = np.mean(df_202001[df_202001.isnull() == False][['0시', '1시', '2시', '3시', '4시', '5시',
#        '6시', '7시', '8시', '9시', '10시', '11시', '12시', '13시', '14시', '15시', '16시',
#        '17시', '18시', '19시', '20시', '21시', '22시', '23시']],axis=1)
#
# df_202001.head()

# %%
tmp_list = []
tmp= pd.DataFrame(cols)

for col in cols:
    
    tmp_list.append( df_202001[df_202001['지점번호']== col ]['Avg'].mean())
    
tmp['1월']=tmp_list

tmp.columns = ['지점번호','1월']

tmp.set_index('지점번호', drop = True, inplace = True)

tmp

# %%
df_202001 = df_202001.astype({'구분': 'str'})
df_202001
# Out:
#             일자 요일        지점명  지점번호  방향            구분      0시      1시      2시  \
# 0     20200101  수  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역   712.0   645.0   437.0
# 1     20200102  목  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역   315.0   222.0   186.0
# 2     20200103  금  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역   632.0   457.0   295.0
# 3     20200104  토  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역   740.0   518.0   388.0
# 4     20200105  일  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역   533.0   424.0   297.0
# ...        ... ..        ...   ...  ..           ...     ...     ...     ...
# 8365  20200127  월     서부간선도로  F-09  유출      목동교->신정교  2061.0  1576.0  1152.0
# 8366  20200128  화     서부간선도로  F-09  유출      목동교->신정교  1553.0  1066.0   745.0
# 8367  20200129  수     서부간선도로  F-09  유출      목동교->신정교  2164.0  1425.0  1038.0
# 8368  20200130  목     서부간선도로  F-09  유출      목동교->신정교  2524.0  1752.0  1186.0
# 8369  20200131  금     서부간선도로  F-09  유출      목동교->신정교  2584.0  1777.0  1236.0
#
# ...

# %%
start_list = []
end_list = []

for i in df_202001['구분'].str.split('->') :
    start_list.append(i[0])
    end_list.append(i[1])
    
df_202001.head()
# Out:
#          일자 요일        지점명  지점번호  방향            구분     0시     1시     2시     3시  \
# 0  20200101  수  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  712.0  645.0  437.0  309.0
# 1  20200102  목  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  315.0  222.0  186.0  165.0
# 2  20200103  금  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  632.0  457.0  295.0  236.0
# 3  20200104  토  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  740.0  518.0  388.0  331.0
# 4  20200105  일  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  533.0  424.0  297.0  230.0
#
#    ...     14시     15시     16시     17시     18시     19시     20시     21시  \
# 0  ...  1472.0  1416.0  1483.0  1329.0  1157.0  1014.0   954.0   849.0
# 1  ...  1792.0  1897.0  1842.0  2061.0  1994.0  1443.0  1233.0  1165.0
# 2  ...  2004.0  1929.0  2049.0  2140.0  2178.0  1654.0  1356.0  1260.0
# 3  ...  1837.0  1788.0  1588.0  1669.0  1530.0  1222.0  1143.0  1089.0
# 4  ...  1634.0  1673.0  1494.0  1429.0  1288.0  1035.0   987.0   884.0
#
#       22시    23시
# 0   780.0  480.0
# 1  1094.0  852.0
# ...

# %%
df_202001['start_point']=start_list
df_202001['end_point']=end_list

df_202001.tail()
# Out:
#             일자 요일     지점명  지점번호  방향        구분      0시      1시      2시     3시  \
# 8365  20200127  월  서부간선도로  F-09  유출  목동교->신정교  2061.0  1576.0  1152.0  958.0
# 8366  20200128  화  서부간선도로  F-09  유출  목동교->신정교  1553.0  1066.0   745.0  679.0
# 8367  20200129  수  서부간선도로  F-09  유출  목동교->신정교  2164.0  1425.0  1038.0  809.0
# 8368  20200130  목  서부간선도로  F-09  유출  목동교->신정교  2524.0  1752.0  1186.0  910.0
# 8369  20200131  금  서부간선도로  F-09  유출  목동교->신정교  2584.0  1777.0  1236.0  907.0
#
#       ...     16시     17시     18시     19시     20시     21시     22시     23시  \
# 8365  ...  3057.0  2868.0  3173.0  2872.0  2965.0  2986.0  2582.0  2084.0
# 8366  ...  2817.0  2734.0  2630.0  2724.0  3260.0  3309.0  3143.0  2817.0
# 8367  ...  2870.0  2666.0  2361.0  2687.0  3107.0  3279.0  3272.0  3074.0
# 8368  ...  2686.0  2643.0  2173.0  2106.0  2992.0  3314.0  3311.0  3104.0
# 8369  ...  2666.0  2509.0  2011.0  2345.0  2979.0  3099.0  3247.0  3197.0
#
#       start_point  end_point
# ...

# %% [markdown]
# df_202001[['지점번호','Avg']].head(50)

# %%
point = df_202001[['지점번호','지점명', 'start_point','end_point']][df_202001['방향']=='유입']
point
# Out:
#       지점번호        지점명 start_point end_point
# 0     A-01  성산로(금화터널)      봉원고가차도      독립문역
# 1     A-01  성산로(금화터널)      봉원고가차도      독립문역
# 2     A-01  성산로(금화터널)      봉원고가차도      독립문역
# 3     A-01  성산로(금화터널)      봉원고가차도      독립문역
# 4     A-01  성산로(금화터널)      봉원고가차도      독립문역
# ...    ...        ...         ...       ...
# 8334  F-09     서부간선도로         신정교       목동교
# 8335  F-09     서부간선도로         신정교       목동교
# 8336  F-09     서부간선도로         신정교       목동교
# 8337  F-09     서부간선도로         신정교       목동교
# 8338  F-09     서부간선도로         신정교       목동교
#
# [4185 rows x 4 columns]

# %%
point = point.drop_duplicates()

point
# Out:
#       지점번호          지점명 start_point end_point
# 0     A-01    성산로(금화터널)      봉원고가차도      독립문역
# 62    A-02    사직로(사직터널)        독립문역       사직단
# 124   A-03  자하문로(자하문터널)         석파정    청운초등학교
# 186   A-04   대사관로(삼청터널)         삼청각    삼청공원입구
# 248   A-05     율곡로(안국역)         안국역    안국동사거리
# ...    ...          ...         ...       ...
# 8060  F-05       동부간선도로         장안교       군자교
# 8122  F-06       경부고속도로        서초IC      반포IC
# 8184  F-07        분당수서로        수서IC      탄천1교
# 8246  F-08        강남순환로       금천요금소      관악IC
# 8308  F-09       서부간선도로         신정교       목동교
#
# [135 rows x 4 columns]

# %%
month_avg_2020 = pd.merge(left = tmp,
                         right = point,
                         how = 'left',
                         left_on = '지점번호',
                         right_on = '지점번호')


month_avg_2020[month_avg_2020['start_point']=='남산2호터널북단']

# %%
#*********GPS
# 필요한 모듈 가져오기 => json 파싱을 위해 들고옴
# 최소한 사용하기 직전에만 모듈 가져오기를 수행하면 된다 / 코드 어느 위치든 상관 없음
import urllib.request
import os
import sys
import json

# %%
# 바뀔일이 없는 정보는 대문자 변수로 설정하여 상수화
target_url = 'https://dapi.kakao.com/v2/local/search/keyword.json'
KAKAO_API = 'KakaoAK 8496a029241807d997d53db97f23e968'
KEY = '서울 '

# 항수화 
# 입력 : 검색어
# 출력 : addr, lat, lng
# 함수명 : getGPSbyKeyword

def getGPSbyKeyword(keyword):
    keyword =   urllib.parse.quote(keyword)
    request = urllib.request.Request(f'{target_url}?query={keyword}')
    
    request.add_header('Authorization', KAKAO_API)
    response = urllib.request.urlopen( request )
    
    if response.getcode() == 200:
        tmp = json.load(response)
        if len(tmp['documents'])==0:
            
            print(tmp)
            return ' ',' ',' '
        else:
            print(tmp)
            addr, lat, lng = tmp['documents'][0]['address_name'], tmp['documents'][0]['y'], tmp['documents'][0]['x']
        
        return addr, lat, lng
    else:
      # 통신 실패 
        addr, lat, lng = ('',0,0)
        return addr, lat, lng

# %%
getGPSbyKeyword('성산로')
# Out:
# {'documents': [{'address_name': '서울 마포구 성산동 275-3', 'category_group_code': '', 'category_group_name': '', 'category_name': '교육,학문 > 학습시설 > 도서관', 'distance': '', 'id': '2019177712', 'phone': '02-3153-5800', 'place_name': '마포중앙도서관', 'place_url': 'http://place.map.kakao.com/2019177712', 'road_address_name': '서울 마포구 성산로 128', 'x': '126.90811796211945', 'y': '37.563736903564376'}, {'address_name': '서울 서대문구 연희동 446-4', 'category_group_code': 'OL7', 'category_group_name': '주유소,충전소', 'category_name': '교통,수송 > 자동차 > 주유,가스 > 주유소 > SK주유소', 'distance': '', 'id': '8347958', 'phone': '02-334-4919', 'place_name': '삼미상사 서부주유소', 'place_url': 'http://place.map.kakao.com/8347958', 'road_address_name': '서울 서대문구 성산로 255', 'x': '126.918936537927', 'y': '37.5676650602795'}, {'address_name': '서울 서대문구 대신동 16-7', 'category_group_code': 'OL7', 'category_group_name': '주유소,충전소', 'category_name': '교통,수송 > 자동차 > 주유,가스 > 주유소 > SK주유소', 'distance': '', 'id': '1308203392', 'phone': '02-365-5189', 'place_name': '행촌제2주유
# ...

# %%
getGPSbyKeyword('남산2호터널북단')
# Out:
# (' ', ' ', ' ')

# %%
start_addr = list()
start_lat = list()
start_lng = list()

for i in point['start_point']:
    print(i)
    a,b,c = getGPSbyKeyword(i)
    print(a,b,c,i)
    start_addr.append(a)
    start_lat.append(b)
    start_lng.append(c)


month_avg_2020.head()
# Out:
# 봉원고가차도
# 서울 서대문구 대신동 37.5659400231843 126.946452440577 봉원고가차도
# 독립문역
# 서울 종로구 무악동 41-6 37.5744680817828 126.957915974354 독립문역
# 석파정
# 서울 종로구 부암동 201 37.5950231297339 126.962651139577 석파정
# 삼청각
# 서울 성북구 성북동 330-230 37.5975974409627 126.982991777284 삼청각
# 안국역
# 서울 종로구 경운동 95 37.576500118896 126.985423696742 안국역
# 성균관대입구
# 서울 종로구 명륜2가 37.5830386240056 126.998741047936 성균관대입구
# 혜화동로터리
# 서울 종로구 혜화동 37.585546989449 127.001231821768 혜화동로터리
# 신설동역
# 서울 동대문구 신설동 76-22 37.5760299683175 127.024456700382 신설동역
# 상왕십리역
# 서울 성동구 하왕십리동 960-3 37.564438467635 127.029274674797 상왕십리역
# 약수역
# 서울 중구 신당동 369-44 37.5545053994984 127.010891666957 약수역
# 남산2호터널북단
#       남산2호터널북단
# 서울역
# 서울 용산구 동자동 43-227 37.5533307290007 126.969747353686 서울역
# 서울역
# 서울 용산구 동자동 43-227 37.5533307290007 126.969747353686 서울역
# 서울역사박물관
# 서울 종로구 신문로2가 2-1 37.5705003227005 126.970546366796 서울역사박물관
# 종로3가
# 서울 종로구 종로3가 143-1 37.5702516183839 126.995146166002 종로3가
# 경찰청앞
# 서울 중구 의주로1가 37.5621244323259 126.969630614828 경찰청앞
# 서울시의회
# ...

# %%
point['start_addr'] = start_addr
point['start_lat'] = start_lat
point['start_lng'] = start_lng

point.head()
# Out:
# C:\Users\guswj\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\guswj\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\guswj\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
name = []

for i in point['지점명'].str.split('(') :
    name.append(i[0])
    
point['name'] = name
point.head()
# Out:
# C:\Users\guswj\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      지점번호          지점명 start_point end_point          start_addr  \
# 0    A-01    성산로(금화터널)      봉원고가차도      독립문역         서울 서대문구 대신동
# 62   A-02    사직로(사직터널)        독립문역       사직단     서울 종로구 무악동 41-6
# 124  A-03  자하문로(자하문터널)         석파정    청운초등학교      서울 종로구 부암동 201
# 186  A-04   대사관로(삼청터널)         삼청각    삼청공원입구  서울 성북구 성북동 330-230
# 248  A-05     율곡로(안국역)         안국역    안국동사거리       서울 종로구 경운동 95
#
#             start_lat         start_lng  name
# 0    37.5659400231843  126.946452440577   성산로
# 62   37.5744680817828  126.957915974354   사직로
# 124  37.5950231297339  126.962651139577  자하문로
# ...

# %%
end_addr = list()
end_lat = list()
end_lng = list()

for i in point['end_point']:
    print(i)
    a,b,c = getGPSbyKeyword(i)
    print(a,b,c,i)
    end_addr.append(a)
    end_lat.append(b)
    end_lng.append(c)
# Out:
# 독립문역
# 서울 종로구 무악동 41-6 37.5744680817828 126.957915974354 독립문역
# 사직단
# 서울 종로구 사직동 1-28 37.5756532581652 126.967659901279 사직단
# 청운초등학교
# 서울 종로구 청운동 123 37.585964668182 126.969299388539 청운초등학교
# 삼청공원입구
# 서울 종로구 삼청동 37.5869511275298 126.98170800899 삼청공원입구
# 안국동사거리
# 서울 종로구 송현동 37.5756528679359 126.983055635678 안국동사거리
# 원남동사거리
# 서울 종로구 원남동 37.5759099369174 126.997360075255 원남동사거리
# 이화사거리
# 서울 종로구 연건동 37.5761478092222 127.002159945298 이화사거리
# 동묘앞역
# 서울 종로구 숭인동 81-39 37.5732166600283 127.016364227103 동묘앞역
# 신당역
# 서울 중구 황학동 757 37.5656730531732 127.019477533278 신당역
# 장충체육관
# 서울 중구 장충동2가 200-102 37.558178171371 127.006808757736 장충체육관
# 장충체육관
# 서울 중구 장충동2가 200-102 37.558178171371 127.006808757736 장충체육관
# 회현역
# 서울 중구 남창동 116-1 37.558760244882336 126.97843725718793 회현역
# 숭례문
# 서울 중구 남대문로4가 29 37.5600030088843 126.975313124237 숭례문
# 광화문역
# 서울 종로구 세종로 186 37.5716477085545 126.976423148119 광화문역
# 종로2가
# 서울 종로구 종로2가 38-2 37.5715557705386 126.988209324531 종로2가
# 시청역
# ...

# %%
point['end_addr'] = end_addr
point['end_lat'] = end_lat
point['end_lng'] = end_lng

point.head()
# Out:
# C:\Users\guswj\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\guswj\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\guswj\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
name_addr = list()
name_lat = list()
name_lng = list()

for i in point['name']:
    print(i)
    a,b,c = getGPSbyKeyword(i)
    print(a,b,c,i)
    name_addr.append(a)
    name_lat.append(b)
    name_lng.append(c)
# Out:
# 성산로
# 서울 마포구 성산동 275-3 37.563736903564376 126.90811796211945 성산로
# 사직로
# 서울 종로구 적선동 80 37.5755140820249 126.973161662111 사직로
# 자하문로
# 서울 종로구 적선동 100-1 37.576378971195886 126.97287494298497 자하문로
# 대사관로
# 서울 성북구 성북동 330-105 37.595893443325 126.98863124751 대사관로
# 율곡로
# 서울 종로구 종로6가 289-11 37.57015398850458 127.00998385259766 율곡로
# 창경궁로
# 서울 종로구 명륜2가 198-2 37.5832260305378 126.998731987549 창경궁로
# 대학로
# 경기 시흥시 정왕동 2537-1 37.3687899300391 126.73146993008913 대학로
# 종로
# 서울 종로구 구기동 37.6085178126134 126.956370136898 종로
# 퇴계로
# 서울 중구 충무로2가 65-9 37.561320146600636 126.98543344554172 퇴계로
# 동호로
# 서울 중구 을지로5가 275-3 37.5658944720562 127.002698429626 동호로
# 장충단로
# 서울 중구 을지로6가 17-2 37.56887836495422 127.00746625495361 장충단로
# 퇴계로
# 서울 중구 충무로2가 65-9 37.561320146600636 126.98543344554172 퇴계로
# 세종대로
# 서울 중구 태평로2가 360-1 37.5647028748099 126.976629074232 세종대로
# 새문안로
# 서울 중구 충정로1가 75-1 37.56628134476508 126.96854456956765 새문안로
# 종로
# 서울 종로구 구기동 37.6085178126134 126.956370136898 종로
# 서소문로
# ...

# %%
month_avg_2020['name_addr'] = name_addr
month_avg_2020['name_lat'] = name_lat
month_avg_2020['name_lng'] = name_lng

month_avg_2020.head()

# %%
position_code = month_avg_2020[['name', 'name_addr', 'name_lat', 'name_lng','start_point', 'start_addr', 'start_lat', 'start_lng','end_point', 'end_addr', 'end_lat', 'end_lng']]
position_code

# %%
position_code.to_csv(f'C:/Users/guswj/Desktop/py_projects/Project_AirCleaning/data/position_code.csv',encoding='cp949',sep=',')

# %%
#카카오 위도 경도 추가하기
KAKAO_API_KEY = '82c98d95311db94dd3cfbfb486c49927' # RestAPIKey
'''
curl -v -X GET "https://dapi.kakao.com/v2/local/search/address.json" --data-urlencode "query=서울종로경찰서" -H "Authorization: KakaoAK 82c98d95311db94dd3cfbfb486c49927"
'''
target_url = 'https://dapi.kakao.com/v2/local/search/keyword.json'
KAKAO_API = 'KakaoAK 82c98d95311db94dd3cfbfb486c49927'

    keyword = list()
    start_latY= list()
    lngX= list()
    placename = list()
    addr=list()
    for i in  range(len(globals()[f'astr{name}'])):
       
        keyword= urllib.parse.quote("서울 "+globals()[f'astr{name}']['행정동'][i])
        #1. 요청객체 생성
        request = urllib.request.Request(f'{target_url}?query={keyword}')
        #2. 헤더에 키 설정
        request.add_header('Authorization' , KAKAO_API)   
        #3. 통신
        response = urllib.request.urlopen(request)
        #4. 통신 결과 확인 -> 응답코드 200 , 오류코드 500 ,페이지없음 404 , 권한없음 405

        if response.getcode() == 200:
            #통신성공처리 -> postman으로 통신 수행 및 응답결과 확인 했음(구조)
            #결과 json이다 => json 처리하는 모듈이 필요 
            tmp = json.load(response)
            행정동.append(globals()[f'astr{name}']['행정동'][i])
            addr.append(tmp['documents'][0]['address_name']) 
            latY.append(tmp['documents'][0]['y'])
            lngX.append(tmp['documents'][0]['x'])
            placename.append(tmp['documents'][0]['place_name'])
            # print(tmp)
        else :
            #실패시처리

            print("error code", response.getcode())
    break

# %%
#  평균 뽑기

df_201701['mean'] = np.mean(df_201701[df_201701.isnull() == False][['0시', '1시', '2시', '3시', '4시', '5시',
       '6시', '7시', '8시', '9시', '10시', '11시', '12시', '13시', '14시', '15시', '16시',
       '17시', '18시', '19시', '20시', '21시', '22시', '23시']],axis=1)


df_201701.head()

# %%
    tmp_list = []
    tmp= pd.DataFrame(cols)

    for col in cols:

        tmp_list.append( df_201701[df_201701['지점번호']== col ]['mean'].mean())

    tmp['201701']=tmp_list

tmp.columns = ['지점번호','201701']

tmp.set_index('지점번호', drop = True, inplace = True)

tmp

# %%
cols =df_201701['지점번호'].unique()
tmp= pd.DataFrame(cols)


for i in range(2017,2019,1):
    for j in range(1,13,1):
        
        target_name = f'{i}년 {j:02}월'
        path = ORIGIN_PATH + f'Seoul_Traffic/{i}/{j}월 서울시 교통량 조사자료.xlsx' 
        print(path)
        target_file=pd.read_excel(path,encoding='utf-8',sheet_name=0, index_col=0)
        target_file['mean'] = np.mean(target_file[target_file.isnull() == False][['0시', '1시', '2시', '3시', '4시', '5시',
       '6시', '7시', '8시', '9시', '10시', '11시', '12시', '13시', '14시', '15시', '16시',
       '17시', '18시', '19시', '20시', '21시', '22시', '23시']],axis=1)
        
        tmp_list = []

        for col in cols:
            tmp_list.append( target_file[target_file['지점번호']== col ]['mean'].mean())

        tmp[target_name]=tmp_list
        print(tmp)

# %%
tmp

# %%
   
for i in range(2019,2020,1):
    for j in range(1,13,1):
        
        target_name = f'{i}년 {j:02}월'
        path = ORIGIN_PATH + f'Seoul_Traffic/{i}/{j}월 서울시 교통량 조사자료.xlsx' 
        print(path)
        target_file=pd.read_excel(path,encoding='utf-8',sheet_name=1, index_col=0)
        target_file['mean'] = np.mean(target_file[target_file.isnull() == False][['0시', '1시', '2시', '3시', '4시', '5시',
               '6시', '7시', '8시', '9시', '10시', '11시', '12시', '13시', '14시', '15시', '16시', '17시', '18시', '19시', 
                '20시', '21시', '22시', '23시']],axis=1)
        
        tmp_list = []

        for col in cols:
            tmp_list.append( target_file[target_file['지점번호']== col ]['mean'].mean())

        tmp_list
        tmp[target_name]=tmp_list
        print(tmp)

# %%
for i in range(2020,2021,1):
    for j in range(1,7,1):
        
        target_name = f'{i}년 {j:02}월'
        path = ORIGIN_PATH + f'Seoul_Traffic/{i}/{j:02}월 서울시 교통량 조사자료.xlsx' 
        print(path)
        target_file=pd.read_excel(path,encoding='utf-8',sheet_name=1, index_col=0)
        target_file['mean'] = np.mean(target_file[target_file.isnull() == False][['0시', '1시', '2시', '3시', '4시', '5시',
               '6시', '7시', '8시', '9시', '10시', '11시', '12시', '13시', '14시', '15시', '16시', '17시', '18시', '19시', 
                '20시', '21시', '22시', '23시']],axis=1)
        
        tmp_list = []

        for col in cols:
            tmp_list.append( target_file[target_file['지점번호']== col ]['mean'].mean())

        tmp_list
        tmp[target_name]=tmp_list
        print(tmp)

# %%
tmp.head()

# %%
# tmp.set_index(0, drop = True, inplace = True)
tmp.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-f1bc72c84419> in <module>
#       1 # tmp.set_index(0, drop = True, inplace = True)
# ----> 2 tmp.head()
#
# NameError: name 'tmp' is not defined

# %%
cols = tmp.columns

for col in cols:
    tmp[col] = tmp[col].round(2)
    
tmp.head()

# %%
tmp.to_csv(f'C:/Users/guswj/Desktop/py_projects/Project_AirCleaning/data/month_mean.csv',encoding='cp949',sep=',')
